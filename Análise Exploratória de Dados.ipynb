# %% [markdown]
# ## Introdução à Ciência de Dados - Lista de exercícios 2
#
# Amanda Caroline de Oliveira Pires
#
# 12559090

# %% [markdown]
# # Exercício 1

# %%
import numpy as np
import matplotlib.pyplot as plt

lmbd = 1 # taxa
n = 100
p = np.random.poisson(lmbd, n)
k = np.arange(0, np.max(p))
count, bins, ignored = plt.hist(p, bins=k, density=True, color ='#483D8B', alpha=0.7,
                                rwidth=0.9)
plt.xlabel('k', fontsize = 15)
plt.ylabel('P(k)', fontsize = 15)
plt.title('Lambda = 1', fontsize = 16)
plt.show(True)

lmbd = 2 # taxa
n = 1000
p = np.random.poisson(lmbd, n)
k = np.arange(0, np.max(p))
count, bins, ignored = plt.hist(p, bins=k, density=True, color ='#483D8B', alpha=0.7,
                                rwidth=0.9)
plt.xlabel('k', fontsize = 15)
plt.ylabel('P(k)', fontsize = 15)
plt.title('Lambda = 2', fontsize = 16)
plt.show(True)

lmbd = 3 # parâmetro de taxa
n = 1000
p = np.random.poisson(lmbd, n)
k = np.arange(0, np.max(p))
count, bins, ignored = plt.hist(p, bins=k, density=True, color ='#483D8B', alpha=0.7,
                                rwidth=0.9)
plt.xlabel('k', fontsize = 15)
plt.ylabel('P(k)', fontsize = 15)
plt.title('Lambda = 3', fontsize = 16)
plt.show(True)

lmbd = 4 # parâmetro de taxa
n = 1000
p = np.random.poisson(lmbd, n)
k = np.arange(0, np.max(p))
count, bins, ignored = plt.hist(p, bins=k, density=True, color ='#483D8B', alpha=0.7,
                                rwidth=0.9)
plt.xlabel('k', fontsize = 15)
plt.ylabel('P(k)', fontsize = 15)
plt.title('Lambda = 4', fontsize = 16)
plt.show(True)

lmbd = 5 # parâmetro de taxa
n = 1000
p = np.random.poisson(lmbd, n)
k = np.arange(0, np.max(p))
count, bins, ignored = plt.hist(p, bins=k, density=True, color ='#483D8B', alpha=0.7,
                                rwidth=0.9)
plt.xlabel('k', fontsize = 15)
plt.ylabel('P(k)', fontsize = 15)
plt.title('Lambda = 5', fontsize = 16)
plt.show(True)

lmbd = 6 # taxa
n = 100
p = np.random.poisson(lmbd, n)
k = np.arange(0, np.max(p))
count, bins, ignored = plt.hist(p, bins=k, density=True, color ='#483D8B', alpha=0.7,
                                rwidth=0.9)
plt.xlabel('k', fontsize = 15)
plt.ylabel('P(k)', fontsize = 15)
plt.title('Lambda = 6', fontsize = 16)
plt.show(True)

lmbd = 7 # taxa
n = 1000
p = np.random.poisson(lmbd, n)
k = np.arange(0, np.max(p))
count, bins, ignored = plt.hist(p, bins=k, density=True, color ='#483D8B', alpha=0.7,
                                rwidth=0.9)
plt.xlabel('k', fontsize = 15)
plt.ylabel('P(k)', fontsize = 15)
plt.title('Lambda = 7', fontsize = 16)
plt.show(True)

lmbd = 8 # parâmetro de taxa
n = 1000
p = np.random.poisson(lmbd, n)
k = np.arange(0, np.max(p))
count, bins, ignored = plt.hist(p, bins=k, density=True, color ='#483D8B', alpha=0.7,
                                rwidth=0.9)
plt.xlabel('k', fontsize = 15)
plt.ylabel('P(k)', fontsize = 15)
plt.title('Lambda = 8', fontsize = 16)
plt.show(True)

lmbd = 9 # parâmetro de taxa
n = 1000
p = np.random.poisson(lmbd, n)
k = np.arange(0, np.max(p))
count, bins, ignored = plt.hist(p, bins=k, density=True, color ='#483D8B', alpha=0.7,
                                rwidth=0.9)
plt.xlabel('k', fontsize = 15)
plt.ylabel('P(k)', fontsize = 15)
plt.title('Lambda = 9', fontsize = 16)
plt.show(True)

lmbd = 10 # parâmetro de taxa
n = 1000
p = np.random.poisson(lmbd, n)
k = np.arange(0, np.max(p))
count, bins, ignored = plt.hist(p, bins=k, density=True, color ='#483D8B', alpha=0.7,
                                rwidth=0.9)
plt.xlabel('k', fontsize = 15)
plt.ylabel('P(k)', fontsize = 15)
plt.title('Lambda = 10', fontsize = 16)
plt.show(True)

# %%
import numpy as np
import pandas as pd

# Leitura dos dados
data = pd.read_csv("C:/Users/Amanda/Desktop/iris.csv")
#data.head(25)

# %%
# Este comando nos fornece algumas medidas de posição dos dados
data.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %% [markdown]
# # **Exercício 2**

# %% [markdown]
# ## Média
#
# Média da coluna **"sepal_length"**

# %%
import pandas as pd
mean = data['sepal_length'].mean()
 
# Print mean
print(mean)
# Out:
# 5.843333333333335

# %% [markdown]
# Média da coluna **"sepal_width"**

# %%
import pandas as pd
mean = data['sepal_width'].mean()

print(mean)
# Out:
# 3.0540000000000007

# %% [markdown]
# Média da coluna **"petal_length"**

# %%
import pandas as pd
mean = data['petal_length'].mean()
 
print(mean)
# Out:
# 3.7586666666666693

# %% [markdown]
# Média da coluna **"petal_width"**

# %%
import pandas as pd
mean = data['sepal_width'].mean()

print(mean)
# Out:
# 3.0540000000000007

# %% [markdown]
# ## Variância
#
# Calculando a variância **"sepal_length"**

# %%
import pandas as pd
var = data['sepal_length'].var()

print(var)
# Out:
# 0.6856935123042505

# %% [markdown]
# Calculando a variância **"petal_length"**

# %%
import pandas as pd
var = data['petal_length'].var()

print('A variância da petal_length é:',var)
# Out:
# A variância da petal_length é: 3.1131794183445156

# %% [markdown]
# Calculando a variância **"sepal_width"**

# %%
import pandas as pd
var = data['sepal_width'].var()

print('A variância da sepal_width é:', var)
# Out:
# A variância da sepal_width é: 0.18800402684563763

# %% [markdown]
# Calculando a variância **"petal_width"**

# %%
import pandas as pd
var = data['petal_width'].std()

print('A variância da petal_width é:', var)
# Out:
# A variância da petal_width é: 0.7631607417008414

# %% [markdown]
# ## **IQR**

# %% [markdown]
# Calculando o IQR **"sepal_length"**

# %%
# Função que calcula os quantis

Q1 = data['sepal_length'].quantile(0.25)
Q2 = data['sepal_length'].quantile(0.50)
Q3 = data['sepal_length'].quantile(0.75)
print('Primeiro quartil ', Q1)
print('Segundo quartil (Mediana)', Q2)
print('Terceiro quartil ', Q3)

# Intervalo interquartil (IQR)

IQR = Q3 - Q1  # diferença entre o terceiro e primeiro quartil
print('Intervalo interquartil "sepal_length": ', IQR)
# Out:
# Primeiro quartil  5.1
# Segundo quartil (Mediana) 5.8
# Terceiro quartil  6.4
# Intervalo interquartil "sepal_length":  1.3000000000000007

# %% [markdown]
# Calculando o IQR **"sepal_width"**

# %%
# Função que calcula os quantis

Q1 = data['sepal_width'].quantile(0.25)
Q2 = data['sepal_width'].quantile(0.50)
Q3 = data['sepal_width'].quantile(0.75)
print('Primeiro quartil ', Q1)
print('Segundo quartil (Mediana)', Q2)
print('Terceiro quartil ', Q3)

# Intervalo interquartil (IQR)

IQR = Q3 - Q1  # diferença entre o terceiro e primeiro quartil
print('Intervalo interquartil "sepal_width": ', IQR)
# Out:
# Primeiro quartil  2.8
# Segundo quartil (Mediana) 3.0
# Terceiro quartil  3.3
# Intervalo interquartil "sepal_width":  0.5

# %% [markdown]
# Calculando IQR **"petal_length"**

# %%
# Função que calcula os quantis

Q1 = data['petal_length'].quantile(0.25)
Q2 = data['petal_length'].quantile(0.50)
Q3 = data['petal_length'].quantile(0.75)
print('Primeiro quartil ', Q1)
print('Segundo quartil (Mediana)', Q2)
print('Terceiro quartil ', Q3)

# Intervalo interquartil (IQR)

IQR = Q3 - Q1  # diferença entre o terceiro e primeiro quartil
print('Intervalo interquartil "petal_length": ', IQR)
# Out:
# Primeiro quartil  1.6
# Segundo quartil (Mediana) 4.35
# Terceiro quartil  5.1
# Intervalo interquartil "petal_length":  3.4999999999999996

# %% [markdown]
# Calculando IQR **"petal_width"**

# %%
# Função que calcula os quantis

Q1 = data['petal_width'].quantile(0.25)
Q2 = data['petal_width'].quantile(0.50)
Q3 = data['petal_width'].quantile(0.75)
print('Primeiro quartil ', Q1)
print('Segundo quartil (Mediana)', Q2)
print('Terceiro quartil ', Q3)

# Intervalo interquartil (IQR)

IQR = Q3 - Q1  # diferença entre o terceiro e primeiro quartil
print('Intervalo interquartil "petal_width": ', IQR)
# Out:
# Primeiro quartil  0.3
# Segundo quartil (Mediana) 1.3
# Terceiro quartil  1.8
# Intervalo interquartil "petal_width":  1.5

# %% [markdown]
# # **Exercício 3**
#
# ## Boxplot

# %%
# biblioteca para mostrar os gráficos
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

data = pd.read_csv('C:/Users/Amanda/Desktop/iris.csv', header=(0))
plt.figure(figsize=(8, 8))
# mostra o boxplot
sns.boxplot(x="species", y="petal_length", data=data, palette="Pastel2")
plt.xlabel('Espécie', fontsize=18)
plt.ylabel('Comprimento da pétala', fontsize=16)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.show(True)

# %%
# biblioteca para mostrar os gráficos
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

data = pd.read_csv('C:/Users/Amanda/Desktop/iris.csv', header=(0))
plt.figure(figsize=(8, 8))
# mostra o boxplot
sns.boxplot(x="species", y="petal_width", data=data, palette="Pastel2")
plt.xlabel('Espécie', fontsize=18)
plt.ylabel('Largura da pétala', fontsize=16)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.show(True)

# %%
# biblioteca para mostrar os gráficos
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

data = pd.read_csv('C:/Users/Amanda/Desktop/iris.csv', header=(0))
plt.figure(figsize=(8, 8))
# mostra o boxplot
sns.boxplot(x="species", y="sepal_length", data=data, palette="Pastel2")
plt.xlabel('Espécie', fontsize=18)
plt.ylabel('Comprimento da sépala', fontsize=16)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.show(True)

# %%
# biblioteca para mostrar os gráficos
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

data = pd.read_csv('C:/Users/Amanda/Desktop/iris.csv', header=(0))
plt.figure(figsize=(8, 8))
# mostra o boxplot
sns.boxplot(x="species", y="sepal_width", data=data, palette="Pastel2")
plt.xlabel('Espécie', fontsize=18)
plt.ylabel('Largura da sépala', fontsize=16)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.show(True)

# %% [markdown]
# # Exercício 4
#
# ## **Correlação**

# %% [markdown]
# Calculando a correlação de Pearson e Spearman

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import pearsonr

N = 100
X = np.linspace(-1,1, N)
erro = np.random.uniform(-1,1,N) # ruído a ser incluído na relação linear.
for sigma in np.arange(0,2,0.2):
    Y = -0.8*X + erro*sigma
    plt.plot(X,Y, 'ro')
    corr, p_value = pearsonr(X, Y) # calcula a correlação
    corr = int(corr*100)/100
    string = 'corr = '+ str(corr)
    plt.xlim(-1.5,1.5)
    plt.ylim(-2, 2)
    plt.text(0.6,1.7, string, fontsize=15)
    plt.show(True)

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import pearsonr, spearmanr

# Para N=10
N = 10
x = np.linspace(1, 50000, N) 
z = np.log(x)

plt.plot(x, z) 
plt.xlabel("x",fontsize = 20) 
plt.ylabel("Log(X)", fontsize = 20) 
corr, p_value = pearsonr(x, z)
corrs, p_values = spearmanr(x, z)
corr = int(corr*100)/100
corrs = int(corrs*100)/100
string = 'Pearson corr. = '+ str(corr)
plt.text(20000,3, string, fontsize=15)
string = 'Spearman corr. = '+ str(corrs)
plt.text(20000,1, string, fontsize=15)
plt.title('N = 10')
plt.show()


# Para N=100
N1 = 100
x = np.linspace(1, 50000, N1) 
z = np.log(x)

plt.plot(x, z) 
plt.xlabel("x",fontsize = 20) 
plt.ylabel("Log(X)", fontsize = 20) 
corr, p_value = pearsonr(x, z)
corrs, p_values = spearmanr(x, z)
corr = int(corr*100)/100
corrs = int(corrs*100)/100
string = 'Pearson corr. = '+ str(corr)
plt.text(20000,3, string, fontsize=15)
string = 'Spearman corr. = '+ str(corrs)
plt.text(20000,1, string, fontsize=15)
plt.title('N = 100')
plt.show()

# Para N=1000
N2= 1000
x = np.linspace(1, 50000, N2) 
z = np.log(x)

plt.plot(x, z) 
plt.xlabel("x",fontsize = 20) 
plt.ylabel("Log(X)", fontsize = 20) 
corr, p_value = pearsonr(x, z)
corrs, p_values = spearmanr(x, z)
corr = int(corr*100)/100
corrs = int(corrs*100)/100
string = 'Pearson corr. = '+ str(corr)
plt.text(20000,3, string, fontsize=15)
string = 'Spearman corr. = '+ str(corrs)
plt.text(20000,1, string, fontsize=15)
plt.title('N = 1000')
plt.show()

# %% [markdown]
# Percebe-se que o coeficiente de Spearman é sempre maior que o coeficiente de Pearson, mesmo com a variação de "N"

# %% [markdown]
# # Exercício 5

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import pearsonr

N = 100
X = np.linspace(-1,1, N)
erro = np.random.uniform(-3,3,N) # ruído a ser incluído na relação linear.
for sigma in np.arange(0,2,0.2):
    Y = -0.5*X + erro*sigma
    plt.plot(X,Y, 'ro')
    corr, p_value = pearsonr(X, Y) # calcula a correlação
    corr = int(corr*100)/100
    string = 'corr = '+ str(corr)
    plt.xlim(-1.5,1.5)
    plt.ylim(-2, 2)
    plt.text(0.6,1.7, string, fontsize=15)
    plt.show(True)

# %% [markdown]
# Coeficientes de Pearson e Spearman

# %%
# Para N=100
N = 100
x = np.linspace(1, 50000, N) 
y = np.log(x)

plt.plot(x, y) 
plt.xlabel("x",fontsize = 20) 
plt.ylabel("Log(X)", fontsize = 20) 
corr, p_value = pearsonr(x, y)
corrs, p_values = spearmanr(x, y)
corr = int(corr*100)/100
corrs = int(corrs*100)/100
string = 'Pearson corr. = '+ str(corr)
plt.text(20000,3, string, fontsize=15)
string = 'Spearman corr. = '+ str(corrs)
plt.text(20000,1, string, fontsize=15)
plt.title('N = 100')
plt.show()

# %% [markdown]
# # Exercício 6

# %%
import matplotlib.pyplot as plt
import numpy as np

# Quarteto de Ascomb

x = [10, 8, 13, 9, 11, 14, 6, 4, 12, 7, 5]
y1 = [8.04, 6.95, 7.58, 8.81, 8.33, 9.96, 7.24, 4.26, 10.84, 4.82, 5.68]
y2 = [9.14, 8.14, 8.74, 8.77, 9.26, 8.10, 6.13, 3.10, 9.13, 7.26, 4.74]
y3 = [7.46, 6.77, 12.74, 7.11, 7.81, 8.84, 6.08, 5.39, 8.15, 6.42, 5.73]
x4 = [8, 8, 8, 8, 8, 8, 8, 19, 8, 8, 8]
y4 = [6.58, 5.76, 7.71, 8.84, 8.47, 7.04, 5.25, 12.50, 5.56, 7.91, 6.89]

datasets = {
    'I': (x, y1),
    'II': (x, y2),
    'III': (x, y3),
    'IV': (x4, y4)
}

fig, axs = plt.subplots(2, 2, sharex=True, sharey=True, figsize=(10, 5),
                        gridspec_kw={'wspace': 0.08, 'hspace': 0.08})

for ax, (label, (x, y)) in zip(axs.flat, datasets.items()):
    ax.text(0.1, 0.9, label, fontsize=20, transform=ax.transAxes, va='top')
    ax.tick_params(direction='in', top=True, right=True)
    ax.plot(x, y, 'o')
plt.show()

# %%
import numpy as np
mediax = np.mean(x)
mediay1 = np.mean(y1)
mediay2 = np.mean(y2)
mediay3 = np.mean(y3)
mediax4 = np.mean(x4)
mediay4 = np.mean(y4)

print('Média de x:', mediax)
print('Média de y1:', mediay1)
print('Média de y2:', mediay2)
print('Média de y3:', mediay3)
print('Média de x4:', mediax4)
print('Média de y4:', mediay4)
# Out:
# Média de x: 9.0
# Média de y1: 7.500909090909093
# Média de y2: 7.50090909090909
# Média de y3: 7.5
# Média de x4: 9.0
# Média de y4: 7.500909090909091

# %%
varx = np.var(x)
vary1 =np.var(y1)
vary2 =np.var(y2)
vary3 =np.var(y3)
varx4 =np.var(x4)
vary4 =np.var(y4)
print('Variância de x:', varx)
print('Variância de y1', vary1)
print('Variância de y2', vary2)
print('Variância de y3', vary3)
print('Variância de x4', varx4)
print('Variância de y4', vary4)
# Out:
# Variância de x: 10.0
# Variância de y1 3.7520628099173554
# Variância de y2 3.752390082644628
# Variância de y3 3.747836363636364
# Variância de x4 10.0
# Variância de y4 3.7484082644628103

# %%
mediax = np.mean(x)
varx = np.var(x)
mediay = np.mean(y)
vary = np.var(y)

print('A média de x é:', mediax)
print('A variância de x é:', varx)
print('A média de y é:', mediay)
print('A variância de y é:', vary)
# Out:
# A média de x é: 9.0
# A variância de x é: 10.0
# A média de y é: 7.500909090909091
# A variância de y é: 3.7484082644628103

# %% [markdown]
# ## Correlação de Pearson entre as variáveis

# %%
# Para x e y
N1 = 100

corr, p_value = pearsonr(x, y)
corrs, p_values = spearmanr(x, y)
corr = int(corr*100)/100
corrs = int(corrs*100)/100
string = 'Pearson corr. = '+ str(corr)
print('Coeficiente de Pearson:', corr)
print('Coeficiente de Spearman', corrs)
# Out:
# Coeficiente de Pearson: 0.81
# Coeficiente de Spearman 0.5

# %%
# Para x e y1
N1 = 100

corr, p_value = pearsonr(x, y1)
corrs, p_values = spearmanr(x, y1)
corr = int(corr*100)/100
corrs = int(corrs*100)/100
string = 'Pearson corr. = '+ str(corr)
print('Coeficiente de Pearson:', corr)
print('Coeficiente de Spearman', corrs)
# Out:
# Coeficiente de Pearson: -0.52
# Coeficiente de Spearman -0.5

# %%
# Para x e y2
N1 = 100

corr, p_value = pearsonr(x, y2)
corrs, p_values = spearmanr(x, y2)
corr = int(corr*100)/100
corrs = int(corrs*100)/100
string = 'Pearson corr. = '+ str(corr)
print('Coeficiente de Pearson:', corr)
print('Coeficiente de Spearman', corrs)
# Out:
# Coeficiente de Pearson: -0.71
# Coeficiente de Spearman -0.5

# %%
# Para x e y3
N1 = 100

corr, p_value = pearsonr(x, y3)
corrs, p_values = spearmanr(x, y3)
corr = int(corr*100)/100
corrs = int(corrs*100)/100
string = 'Pearson corr. = '+ str(corr)
print('Coeficiente de Pearson:', corr)
print('Coeficiente de Spearman', corrs)
# Out:
# Coeficiente de Pearson: -0.34
# Coeficiente de Spearman -0.5

# %%
# Para x e y4
N1 = 100

corr, p_value = pearsonr(x, y4)
corrs, p_values = spearmanr(x, y4)
corr = int(corr*100)/100
corrs = int(corrs*100)/100
string = 'Pearson corr. = '+ str(corr)
print('Coeficiente de Pearson:', corr)
print('Coeficiente de Spearman', corrs)
# Out:
# Coeficiente de Pearson: 0.81
# Coeficiente de Spearman 0.5

# %%
# Para x4 e y4
N1 = 100

corr, p_value = pearsonr(x4, y4)
corrs, p_values = spearmanr(x4, y4)
corr = int(corr*100)/100
corrs = int(corrs*100)/100
string = 'Pearson corr. = '+ str(corr)
print('Coeficiente de Pearson:', corr)
print('Coeficiente de Spearman', corrs)
# Out:
# Coeficiente de Pearson: 0.81
# Coeficiente de Spearman 0.5

# %% [markdown]
# Como os coeficientes de Pearson e Spearman das variáveis **X** e **Y** são correlacionados **positivamente**, podemos dizer que as variáveis estão **diretamente** correlacionadas.
